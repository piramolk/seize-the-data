# %% [markdown]
# # about
#
# * use some kaggle datasets
#
# An EDA checklist
# 1. What question(s) are you trying to solve (or prove wrong)?
# 2. What kind of data do you have and how do you treat different types?
# 3. What’s missing from the data and how do you deal with it?
# 4. Where are the outliers and why should you care about them?
# 5. How can you add, change or remove features to get more out of your data?
#
# # Pandas
# ## 1. Basic size and shape
# * df.head()/tail : to see what it looks like
# * df.columns : get all column names in case there are too many to be seen
# * df.shape : get the dimensions
#     * helps determine dependent and independent variales
# * df.info()
#     * good to know dtypes in case need to convert
#          * if you do need, do e.g. `df['a'].astype('int')` if u just wanna print or  `df['a'] = df['a'].astype('int')' to change
#          * use `df['a'].dtype` to doublecheck
# * df.describe()
#     * get summary stats
# * if you wanna be more manual
#     * `df.sum()` : sum of values
#     * `df.cumsum()` : cumulative sum of values
#     * `df.min()` , `df.max()` : min/max vals
#     *  `df.idxmin()/df.idxmax()`: Minimum/Maximum index value
#     * `df.mean()` Mean of values
#     * `df.median()` Median of values
#
# * `df['value'].value_counts()` or `missing_value_effect['value'].value_counts(dropna=False)`
#
# ## 2. Make a copy
# * Sometimes, we want to copy the existing dataframe into a new one, to make operations on it without modifying the initial data.
# * good especially if u wanna keep og data as a backup,
# `df2 = df.copy()`
# * Now you can try anything on df2 without the fear of losing the initial data,
#
#
# ## 3. Applying functions
# *  `f = lambda x: x*2`
# * `df.apply(f)` Apply function
# * `df.applymap(f)` Apply function element-wise
#
#
# ----

# %% [markdown]
# # Distribution
# * Get a sense of how the data is distributed/ outliers in the set
# * We will use both graphs and actual summary statistics.
# * The graphs enable us to get an overall idea of the distributions while the statistics give us factual numbers.
# * These two strategies are both recommended as they complement each other.
# ## Numeric features
# ### 1. Plot each numeric feature
# * Use histograms
#     * plot all numeric features in a grid
#         * add figize and xrot arguments

# %%
import pandas as pd
pd.set_option('display.max_columns',100)
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')

# %% [markdown]
# * use melbourne dataset

# %%
df = pd.read_csv('Pandas/melb_data.csv')
df.hist(figsize=(14,14), xrot=45)
plt.show()

# %% [markdown]
# ---
# # Analyzing relationships between variables
#
# ## 1. Correlation Matrix
# * To review, correlation is a measurement that describes the relationship between two variable
# * Thus, a correlation matrix is a table that shows the correlation coefficients between many variables. I used sns.heatmap() to plot a correlation matrix of all of the variables in the used car dataset.

# %%
#Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns

# %%
# calculate correlation matrix
corr = df.corr()# plot the heatmap
plt.figure(figsize=(10,10))
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, cmap=sns.diverging_palette(220, 20, as_cmap=True))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 2. Scatterplot
#
# > A scatterplot is a type of graph which ‘plots’ the values of two variables along two axes, like age and height.
# * Scatterplots are useful for many reasons: like correlation matrices, it allows you to quickly understand a relationship between two variables, it’s useful for identifying outliers, and it’s instrumental when polynomial multiple regression models
# * I used .plot() and set the ‘kind’ of graph as scatter. I also set the x-axis to ‘odometer’ and y-axis as ‘price’, since we want to see how different levels of mileage affects price.

# %%
df.plot(kind='scatter', x='Distance', y='Price')
# Out:
# <AxesSubplot:xlabel='Distance', ylabel='Price'>

# %% [markdown]
# `sns.pairplot(df)`
# ![pairplot.png](attachment:pairplot.png)

# %% [markdown]
# ## 3. Histogram
#
# * Correlation matrices and scatterplots are useful for exploring the relationship between two variables. But what if you only wanted to explore a single variable by itself?
# * This is when histograms come into play. Histograms look like bar graphs but they show the distribution of a variable’s set of values.

# %%
df['Price'].plot(kind='hist', bins=50, figsize=(12,6), facecolor='grey',edgecolor='black')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# * positive skew (right tail)
# * Skewness is important, especially in areas like finance, because a lot of models assume that all variables are normally distributed, which typically isn’t the case.

# %% [markdown]
# # 4. Boxplot

# %%
df.boxplot('Price')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![0_GWZmD1Z7JuZDHlvC.png](attachment:0_GWZmD1Z7JuZDHlvC.png)

# %% [markdown]
# # 5. Violin plot

# %%
import plotly.express as px

# %% [markdown]
# ### basic violin plot
#
# ``
# df = px.data.tips()
# fig = px.violin(df, y="total_bill")
# fig.show()
#
# ``
# ![newplot.png](attachment:newplot.png)

# %% [markdown]
# ### violin plot with box and data points
#
# ``
# df = px.data.tips()
# fig = px.violin(df, y="total_bill", box=True, # draw box plot inside the violin
#                 points='all', # can be 'outliers', or False
#                )
# fig.show()
#
# ``
# ![newplot%20%281%29.png](attachment:newplot%20%281%29.png)
